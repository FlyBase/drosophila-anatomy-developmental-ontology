# %%
#this is for adding extra (simple) annotations to existing terms
#it won't work for just annotations on annotations (eg. adding a ref to an existing defeinition)

# %%
import pandas as pd
import csv
from collections import OrderedDict

# need table with id in column "id" and annotation to be added
raw_data_table = pd.read_csv('./results_list.csv', sep=',', header=None)
raw_data_table = raw_data_table.transpose()
# Out:
# str

# %%
# Make a dictionary with key - column header & value = template specification (first row of table).
# These things are always required by robot
template_seed = OrderedDict([ ('ID' , 'ID'), ('CLASS_TYPE' , 'CLASS_TYPE'),\
                             ('RDF_Type' , 'TYPE' )])

########## EDIT THIS for annotation to be added:
template_seed.update([("Xref" , "A oboInOwl:hasDbXref")])

# Create dataFrame for template
# from_records takes a list of dicts - one for each row.  We only have one row.
template = pd.DataFrame.from_records([template_seed])

template
# Out:
#    ID  CLASS_TYPE RDF_Type                  Xref
# 0  ID  CLASS_TYPE     TYPE  A oboInOwl:hasDbXref

# %%
for i in raw_data_table.index:

    row_od = OrderedDict([]) #new template row as an empty ordered dictionary
    for c in template.columns: #make columns and blank data for new template row
        row_od.update([(c , "")])
    
    #add row info
    row_od["CLASS_TYPE"] = "subclass"
    row_od["RDF_Type"] = "owl:Class"
    row_od["ID"] = raw_data_table[0][i]
    
    ####### EDIT THIS for annotation to be added
    row_od["Xref"] = "VFB:" + raw_data_table[0][i].replace(":","_")
            
    #make new row into a DataFrame and add it to template
    new_row = pd.DataFrame.from_records([row_od])
    template = pd.concat([template, new_row], ignore_index=True, sort=False)
    
template
# Out:
#                  ID  CLASS_TYPE   RDF_Type                  Xref
# 0                ID  CLASS_TYPE       TYPE  A oboInOwl:hasDbXref
# 1     FBbt:00001328    subclass  owl:Class     VFB:FBbt_00001328
# 2     FBbt:00047441    subclass  owl:Class     VFB:FBbt_00047441
# 3     FBbt:00004043    subclass  owl:Class     VFB:FBbt_00004043
# 4     FBbt:00047929    subclass  owl:Class     VFB:FBbt_00047929
# 5     FBbt:00047831    subclass  owl:Class     VFB:FBbt_00047831
# 6     FBbt:00110621    subclass  owl:Class     VFB:FBbt_00110621
# 7     FBbt:00110630    subclass  owl:Class     VFB:FBbt_00110630
# 8     FBbt:00002443    subclass  owl:Class     VFB:FBbt_00002443
# 9     FBbt:00002414    subclass  owl:Class     VFB:FBbt_00002414
# 10    FBbt:00111220    subclass  owl:Class     VFB:FBbt_00111220
# 11    FBbt:00110523    subclass  owl:Class     VFB:FBbt_00110523
# 12    FBbt:00007406    subclass  owl:Class     VFB:FBbt_00007406
# 13    FBbt:00111445    subclass  owl:Class     VFB:FBbt_00111445
# 14    FBbt:00110525    subclass  owl:Class     VFB:FBbt_00110525
# 15    FBbt:00111449    subclass  owl:Class     VFB:FBbt_00111449
# 16    FBbt:00015061    subclass  owl:Class     VFB:FBbt_00015061
# 17    FBbt:00003704    subclass  owl:Class     VFB:FBbt_00003704
# 18    FBbt:00111481    subclass  owl:Class     VFB:FBbt_00111481
# 19    FBbt:00047228    subclass  owl:Class     VFB:FBbt_00047228
# 20    FBbt:00001530    subclass  owl:Class     VFB:FBbt_00001530
# 21    FBbt:00047364    subclass  owl:Class     VFB:FBbt_00047364
# 22    FBbt:00100762    subclass  owl:Class     VFB:FBbt_00100762
# 23    FBbt:00002157    subclass  owl:Class     VFB:FBbt_00002157
# 24    FBbt:00100164    subclass  owl:Class     VFB:FBbt_00100164
# 25    FBbt:00111347    subclass  owl:Class     VFB:FBbt_00111347
# 26    FBbt:00003633    subclass  owl:Class     VFB:FBbt_00003633
# 27    FBbt:00111142    subclass  owl:Class     VFB:FBbt_00111142
# 28    FBbt:00100720    subclass  owl:Class     VFB:FBbt_00100720
# 29    FBbt:00007336    subclass  owl:Class     VFB:FBbt_00007336
# ...             ...         ...        ...                   ...
# 3750  FBbt:00110445    subclass  owl:Class     VFB:FBbt_00110445
# 3751  FBbt:00050247    subclass  owl:Class     VFB:FBbt_00050247
# 3752  FBbt:00110099    subclass  owl:Class     VFB:FBbt_00110099
# 3753  FBbt:00111692    subclass  owl:Class     VFB:FBbt_00111692
# 3754  FBbt:00002397    subclass  owl:Class     VFB:FBbt_00002397
# 3755  FBbt:00100670    subclass  owl:Class     VFB:FBbt_00100670
# 3756  FBbt:00110266    subclass  owl:Class     VFB:FBbt_00110266
# 3757  FBbt:00110477    subclass  owl:Class     VFB:FBbt_00110477
# 3758  FBbt:00067047    subclass  owl:Class     VFB:FBbt_00067047
# 3759  FBbt:00110432    subclass  owl:Class     VFB:FBbt_00110432
# 3760  FBbt:00100163    subclass  owl:Class     VFB:FBbt_00100163
# 3761  FBbt:00002408    subclass  owl:Class     VFB:FBbt_00002408
# 3762  FBbt:00047804    subclass  owl:Class     VFB:FBbt_00047804
# 3763  FBbt:00100712    subclass  owl:Class     VFB:FBbt_00100712
# 3764  FBbt:00012116    subclass  owl:Class     VFB:FBbt_00012116
# 3765  FBbt:00015054    subclass  owl:Class     VFB:FBbt_00015054
# 3766  FBbt:00047661    subclass  owl:Class     VFB:FBbt_00047661
# 3767  FBbt:00001277    subclass  owl:Class     VFB:FBbt_00001277
# 3768  FBbt:00111423    subclass  owl:Class     VFB:FBbt_00111423
# 3769  FBbt:00111322    subclass  owl:Class     VFB:FBbt_00111322
# 3770  FBbt:00002396    subclass  owl:Class     VFB:FBbt_00002396
# 3771  FBbt:00002166    subclass  owl:Class     VFB:FBbt_00002166
# 3772  FBbt:00111765    subclass  owl:Class     VFB:FBbt_00111765
# 3773  FBbt:00003999    subclass  owl:Class     VFB:FBbt_00003999
# 3774  FBbt:00111460    subclass  owl:Class     VFB:FBbt_00111460
# 3775  FBbt:00047587    subclass  owl:Class     VFB:FBbt_00047587
# 3776  FBbt:00110228    subclass  owl:Class     VFB:FBbt_00110228
# 3777  FBbt:00111224    subclass  owl:Class     VFB:FBbt_00111224
# 3778  FBbt:00047683    subclass  owl:Class     VFB:FBbt_00047683
# 3779  FBbt:00110210    subclass  owl:Class     VFB:FBbt_00110210
#
# [3780 rows x 4 columns]

# %%
template.to_csv("./template.tsv", sep = "\t", header=True, index=False)
