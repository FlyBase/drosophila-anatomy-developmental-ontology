# %%
import pandas as pd

# Turn CSV into a pandas DataFrame

connectivity_tab = pd.read_csv('./1-s2.0-S0092867416312429-mmc5.csv', sep=',')

# Show first 10 rows of table

connectivity_tab[0:10]
# Out:
#          Unnamed: 0   A09a a1l Basin-2   A09a a1r Basin-2   A09b a1l Basin-1  \
# 0  A09a a1l Basin-2                  0                  0                  5
# 1  A09a a1r Basin-2                  0                  0                  0
# 2  A09b a1l Basin-1                  0                  0                  0
# 3  A09b a1r Basin-1                  0                  0                  0
# 4  A09c a1l Basin-4                  1                  0                 12
# 5  A09c a1r Basin-4                  0                  0                  0
# 6  A09g a1l Basin-3                  0                  0                 11
# 7  A09g a1r Basin-3                  0                  0                  0
# 8     Drunken-1 a1l                  0                  1                  2
# 9     Drunken-1 a1r                  0                  0                  0
#
#     A09b a1r Basin-1   A09c a1l Basin-4   A09c a1r Basin-4   A09g a1l Basin-3  \
# 0                  0                  0                  0                  0
# 1                 12                  0                  1                  0
# 2                  0                  1                  0                  0
# 3                  0                  0                  1                  0
# 4                  0                  0                  0                  1
# 5                  9                  0                  0                  0
# 6                  0                  1                  0                  0
# 7                  9                  0                  3                  0
# 8                  0                  0                  0                  0
# 9                  0                  0                  0                  0
#
#     A09g a1r Basin-3   Drunken-1 a1l      ...         lch5-3 a1l   lch5-3 a1r  \
# 0                  0               1      ...                  2            0
# 1                  0               0      ...                  0            0
# 2                  0               3      ...                  1            0
# 3                  0               0      ...                  0            5
# 4                  0               0      ...                  0            0
# 5                  1               0      ...                  0            0
# 6                  0               0      ...                  3            0
# 7                  0               0      ...                  0            0
# 8                  0               0      ...                  1            0
# 9                  0               0      ...                  0            2
#
#     lch5-5 a1l   lch5-5 a1r   v'ch a1l   v'ch a1r   vchA/B a1l   vchA/B a1l.1  \
# 0            0            0          2          0            0              1
# 1            0            1          0         13            0              0
# 2            0            0         11          0            5              1
# 3            0            0          0         11            0              0
# 4            0            0          0          0            8              9
# 5            0            0          0          0            0              0
# 6            0            0          0          0           10             11
# 7            0            0          0          3            0              0
# 8            0            0          6          0            0             13
# 9            0            0          0          9            0              0
#
#     vchA/B a1r   vchA/B a1r.1
# 0            0              0
# 1            0              0
# 2            0              0
# 3            4              6
# 4            0              0
# 5            0              3
# 6            0              0
# 7            9             11
# 8            0              0
# 9            4              8
#
# [10 rows x 45 columns]

# %%
# Make a list of column names to use as keys in lookup
columns = list(connectivity_tab.columns)
columns[0:5] # Return first five columns
# Out:
# ['Unnamed: 0',
#  ' A09a a1l Basin-2',
#  ' A09a a1r Basin-2',
#  ' A09b a1l Basin-1',
#  ' A09b a1r Basin-1']

# %%
fbrf_table = pd.read_csv('./fbrf-table.csv', sep=',')
fbrf_table[0:5]
# Out:
#                Keys         Values
# 0  A09a a1l Basin-2  FBbt:00111229
# 1  A09a a1r Basin-2  FBbt:00111229
# 2  A09b a1l Basin-1  FBbt:00111227
# 3  A09b a1r Basin-1  FBbt:00111227
# 4  A09c a1l Basin-4  FBbt:00111230

# %%
# Make a new list without the first (unnamed) column [0]:
#lookup_keys = columns[1:]


# A dictionary (key: value pairs) mapping names from table to FBbt ids
#lookup = { 'A09a a1l Basin-2': 'FBbt:00111229',
#           'A09a a1r Basin-2': 'FBbt:00111229',
#           'A09b a1l Basin-1': 'FBbt:00111227',
#           'A09b a1r Basin-1': 'FBbt:00111227',
#           'A09c a1l Basin-4': 'FBbt:00111230',
#           'A09c a1r Basin-4': 'FBbt:00111230'}  # ... This should be completed for all columns

lookup = dict(zip(fbrf_table.Keys,fbrf_table.Values))

lookup
# Out:
# {'A09a a1l Basin-2': 'FBbt:00111229',
#  'A09a a1r Basin-2': 'FBbt:00111229',
#  'A09b a1l Basin-1': 'FBbt:00111227',
#  'A09b a1r Basin-1': 'FBbt:00111227',
#  'A09c a1l Basin-4': 'FBbt:00111230',
#  'A09c a1r Basin-4': 'FBbt:00111230',
#  'A09g a1l Basin-3': 'FBbt:00111228',
#  'A09g a1r Basin-3': 'FBbt:00111228',
#  'Drunken-1 a1l': 'FBbt:00047195',
#  'Drunken-1 a1r': 'FBbt:00047195',
#  'Griddle-1 a1l': 'FBbt:00047196',
#  'Griddle-1 a1r': 'FBbt:00047196',
#  'Griddle-1 t3l': 'FBbt:00047196',
#  'Griddle-1 t3r': 'FBbt:00047196',
#  'Griddle-2 a1l': 'FBbt:00047197',
#  'Griddle-2 a1r': 'FBbt:00047197',
#  'Griddle-2 t3l': 'FBbt:00047197',
#  'Griddle-2 t3r': 'FBbt:00047197',
#  'Handle-A a1': 'FBbt:00111242',
#  'Handle-B a1': 'FBbt:00111243',
#  'Ladder-a a1': 'FBbt:00047199',
#  'Ladder-a t3': 'FBbt:00047199',
#  'Ladder-b a1': 'FBbt:00047204',
#  'Ladder-c a1': 'FBbt:00047205',
#  'Ladder-d a1': 'FBbt:00047203',
#  'Ladder-e a1': 'FBbt:00047198',
#  'Ladder-f a1': 'FBbt:00047206',
#  'Ladder-f a2': 'FBbt:00047206',
#  'lch5-1 a1l': 'FBbt:00047268',
#  'lch5-1 a1r': 'FBbt:00047268',
#  'lch5-2/4 a1l': 'FBbt:00047266',
#  'lch5-2/4 a1r': 'FBbt:00047266',
#  'lch5-3 a1l': 'FBbt:00047269',
#  'lch5-3 a1r': 'FBbt:00047269',
#  'lch5-5 a1l': 'FBbt:00047270',
#  'lch5-5 a1r': 'FBbt:00047270',
#  "v'ch a1l": 'FBbt:00100024',
#  "v'ch a1r": 'FBbt:00100024',
#  'vchA/B a1l': 'FBbt:00002452',
#  'vchA/B a1r': 'FBbt:00002452'}

# %%
# Make a set (uniqued list) of all values in lookup

neurons = set(lookup.values())
neurons
# Out:
# {'FBbt:00002452',
#  'FBbt:00047195',
#  'FBbt:00047196',
#  'FBbt:00047197',
#  'FBbt:00047198',
#  'FBbt:00047199',
#  'FBbt:00047203',
#  'FBbt:00047204',
#  'FBbt:00047205',
#  'FBbt:00047206',
#  'FBbt:00047266',
#  'FBbt:00047268',
#  'FBbt:00047269',
#  'FBbt:00047270',
#  'FBbt:00100024',
#  'FBbt:00111227',
#  'FBbt:00111228',
#  'FBbt:00111229',
#  'FBbt:00111230',
#  'FBbt:00111242',
#  'FBbt:00111243'}

# %%
# Make a dictionary with key - column header & value = template specification (first row of table).
# Meks first two columns

template_seed = { 'ID': 'ID', 'CLASS_TYPE': 'CLASS_TYPE',  'RDF_Type' : 
'TYPE' }

# The rest of the columns have the neuron id as the column name + template spec in row 1:
data_columns = { n : "C 'synapsed to' some %" for n in neurons }

# Add data columns to template seed

template_seed.update(data_columns)

# Create dataFrame for template
# from_records takes a list of dicts - one for each row.  We only have one row.

template = pd.DataFrame.from_records([template_seed])

# %%
# Iterate over input table rows
## Iterate over rows.

# Using a dict of dicts as an intermediate data structure.  Surely better to assign directly to DataFrame?
rows = {}
for i, r in connectivity_tab.iterrows():
    input_row_key = r[0].lstrip() # use the first column as key for row.  Make sure no trailing/leading whitespace
    # Skip to next iteration if row key not in lookup:
    if not input_row_key in lookup.keys(): continue
    output_row_key = lookup[input_row_key]
    row_dict = { 'ID' : output_row_key, 'CLASS_TYPE' : 'subclass', 'RDF_Type' : 'owl:class'}
    counter = 0
    # iterate over row (k = key/column header, v = value of cell)
    for k,v in r.items():
        key = k.lstrip()  # Turns out that headers have a leading space. This strips it.
        counter += 1
        # Skip the first column
        if counter == 1:
            continue
        # check we can lookup key
        if key in lookup.keys():
            # lookup fbbt ID
            fbbt = lookup[key]
            # default assumption = 0 synapses
            row_dict[fbbt] = ''
            # over-ride default if v > 0 for any key mapping to fbbt
            # v is a string, we need to turn it into an integer before checking it's > 0
            if int(v) > 0:
                row_dict[fbbt] = fbbt
    rows[output_row_key] = row_dict
    
out = template.append(list(rows.values()))
out
# Out:
#     CLASS_TYPE           FBbt:00002452           FBbt:00047195  \
# 0   CLASS_TYPE  C 'synapsed to' some %  C 'synapsed to' some %
# 0     subclass                                   FBbt:00047195
# 1     subclass           FBbt:00002452           FBbt:00047195
# 2     subclass
# 3     subclass           FBbt:00002452           FBbt:00047195
# 4     subclass           FBbt:00002452
# 5     subclass
# 6     subclass                                   FBbt:00047195
# 7     subclass
# 8     subclass                                   FBbt:00047195
# 9     subclass           FBbt:00002452
# 10    subclass
# 11    subclass                                   FBbt:00047195
# 12    subclass
# 13    subclass           FBbt:00002452           FBbt:00047195
# 14    subclass
# 15    subclass                                   FBbt:00047195
# 16    subclass
# 17    subclass                                   FBbt:00047195
# 18    subclass                                   FBbt:00047195
# 19    subclass                                   FBbt:00047195
# 20    subclass                                   FBbt:00047195
#
#              FBbt:00047196           FBbt:00047197           FBbt:00047198  \
# 0   C 'synapsed to' some %  C 'synapsed to' some %  C 'synapsed to' some %
# 0            FBbt:00047196           FBbt:00047197           FBbt:00047198
# 1                                                            FBbt:00047198
# 2
# 3                                                            FBbt:00047198
# 4
# 5                                    FBbt:00047197
# 6            FBbt:00047196                                   FBbt:00047198
# 7                                    FBbt:00047197           FBbt:00047198
# 8            FBbt:00047196                                   FBbt:00047198
# 9            FBbt:00047196           FBbt:00047197           FBbt:00047198
# 10
# 11           FBbt:00047196           FBbt:00047197
# 12           FBbt:00047196                                   FBbt:00047198
# 13           FBbt:00047196
# 14           FBbt:00047196                                   FBbt:00047198
# 15                                                           FBbt:00047198
# 16                                                           FBbt:00047198
# 17                                                           FBbt:00047198
# 18
# 19
# 20
#
#              FBbt:00047199           FBbt:00047203           FBbt:00047204  \
# 0   C 'synapsed to' some %  C 'synapsed to' some %  C 'synapsed to' some %
# 0            FBbt:00047199                                   FBbt:00047204
# 1            FBbt:00047199                                   FBbt:00047204
# 2
# 3            FBbt:00047199                                   FBbt:00047204
# 4
# 5            FBbt:00047199
# 6            FBbt:00047199
# 7            FBbt:00047199                                   FBbt:00047204
# 8            FBbt:00047199                                   FBbt:00047204
# 9                                                            FBbt:00047204
# 10                                   FBbt:00047203
# 11           FBbt:00047199           FBbt:00047203           FBbt:00047204
# 12           FBbt:00047199
# 13           FBbt:00047199           FBbt:00047203           FBbt:00047204
# 14           FBbt:00047199           FBbt:00047203           FBbt:00047204
# 15
# 16
# 17           FBbt:00047199           FBbt:00047203
# 18           FBbt:00047199
# 19
# 20
#
#              FBbt:00047205    ...               FBbt:00047270  \
# 0   C 'synapsed to' some %    ...      C 'synapsed to' some %
# 0                             ...               FBbt:00047270
# 1                             ...
# 2                             ...
# 3                             ...
# 4                             ...
# 5            FBbt:00047205    ...               FBbt:00047270
# 6                             ...
# 7                             ...               FBbt:00047270
# 8            FBbt:00047205    ...               FBbt:00047270
# 9                             ...               FBbt:00047270
# 10                            ...               FBbt:00047270
# 11                            ...               FBbt:00047270
# 12           FBbt:00047205    ...               FBbt:00047270
# 13           FBbt:00047205    ...               FBbt:00047270
# 14           FBbt:00047205    ...
# 15                            ...
# 16                            ...
# 17           FBbt:00047205    ...
# 18                            ...
# 19                            ...
# 20                            ...
#
#              FBbt:00100024           FBbt:00111227           FBbt:00111228  \
# 0   C 'synapsed to' some %  C 'synapsed to' some %  C 'synapsed to' some %
# 0            FBbt:00100024           FBbt:00111227
# 1            FBbt:00100024
# 2                                    FBbt:00111227           FBbt:00111228
# 3            FBbt:00100024           FBbt:00111227
# 4            FBbt:00100024
# 5
# 6
# 7            FBbt:00100024           FBbt:00111227           FBbt:00111228
# 8            FBbt:00100024
# 9
# 10
# 11           FBbt:00100024
# 12
# 13           FBbt:00100024           FBbt:00111227
# 14
# 15
# 16
# 17
# 18
# 19
# 20
#
#              FBbt:00111229           FBbt:00111230           FBbt:00111242  \
# 0   C 'synapsed to' some %  C 'synapsed to' some %  C 'synapsed to' some %
# 0                                    FBbt:00111230
# 1                                    FBbt:00111230
# 2
# 3                                    FBbt:00111230
# 4                                                            FBbt:00111242
# 5
# 6
# 7            FBbt:00111229           FBbt:00111230
# 8            FBbt:00111229           FBbt:00111230           FBbt:00111242
# 9
# 10
# 11
# 12
# 13                                   FBbt:00111230           FBbt:00111242
# 14
# 15
# 16
# 17
# 18
# 19
# 20
#
#              FBbt:00111243             ID   RDF_Type
# 0   C 'synapsed to' some %             ID       TYPE
# 0                           FBbt:00111229  owl:class
# 1                           FBbt:00111227  owl:class
# 2                           FBbt:00111230  owl:class
# 3                           FBbt:00111228  owl:class
# 4            FBbt:00111243  FBbt:00047195  owl:class
# 5            FBbt:00111243  FBbt:00047196  owl:class
# 6                           FBbt:00047197  owl:class
# 7                           FBbt:00111242  owl:class
# 8                           FBbt:00111243  owl:class
# 9            FBbt:00111243  FBbt:00047199  owl:class
# 10                          FBbt:00047204  owl:class
# 11                          FBbt:00047205  owl:class
# 12                          FBbt:00047203  owl:class
# 13           FBbt:00111243  FBbt:00047198  owl:class
# 14                          FBbt:00047206  owl:class
# 15                          FBbt:00047268  owl:class
# 16                          FBbt:00047266  owl:class
# 17                          FBbt:00047269  owl:class
# 18                          FBbt:00047270  owl:class
# 19                          FBbt:00100024  owl:class
# 20                          FBbt:00002452  owl:class
#
# [22 rows x 24 columns]

# %%
out.to_csv("Jovanovic_template.csv", sep=",", index=False)
