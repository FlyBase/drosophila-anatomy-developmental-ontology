# %%
import requests
import json
import pandas as pd
from collections import OrderedDict

#import fbbt
fbbt = requests.get("http://purl.obolibrary.org/obo/fbbt/2018-08-08/fbbt.json").json()
#fbbt.keys()

#compartments
c_infile = pd.read_csv("lb_compartments.tsv", sep="\t")
#c_infile
# Out:
#                        larvalbrain_Name larvalbrain_Shortname  \
# 0                    Abdominal ganglion                    AG
# 1                    Abdominal ganglion                    AG
# 2                  Abdominal ganglion 1                    A1
# 3                  Abdominal ganglion 1                    A1
# 4                  Abdominal ganglion 2                    A2
# 5                  Abdominal ganglion 2                    A2
# 6                  Abdominal ganglion 3                    A3
# 7                  Abdominal ganglion 3                    A3
# 8                  Abdominal ganglion 4                    A4
# 9                  Abdominal ganglion 4                    A4
# 10                 Abdominal ganglion 5                    A5
# 11                 Abdominal ganglion 5                    A5
# 12                 Abdominal ganglion 6                    A6
# 13                 Abdominal ganglion 6                    A6
# 14                 Abdominal ganglion 7                    A7
# 15                 Abdominal ganglion 7                    A7
# 16                 Abdominal ganglion 8                    A8
# 17                 Abdominal ganglion 8                    A8
# 18                 Abdominal ganglion 9                    A9
# 19                 Abdominal ganglion 9                    A9
# 20                        antennal lobe                    AL
# 21                        antennal lobe                    AL
# 22      anterior inferior protocerebrum                  a_IP
# 23      anterior inferior protocerebrum                  a_IP
# 24       anterior ventromedial cerebrum                 a_VMC
# 25       anterior ventromedial cerebrum                 a_VMC
# 26                                calyx                    CA
# 27                                calyx                    CA
# 28        central abdominal ganglion A1                 ci_A1
# 29        central abdominal ganglion A1                 ci_A1
# ..                                  ...                   ...
# 325  ventromedial abdominal ganglion A3                 vm_A3
# 326  ventromedial abdominal ganglion A4                 vm_A4
# 327  ventromedial abdominal ganglion A4                 vm_A4
# 328  ventromedial abdominal ganglion A5                 vm_A5
# 329  ventromedial abdominal ganglion A5                 vm_A5
# 330  ventromedial abdominal ganglion A6                 vm_A6
# 331  ventromedial abdominal ganglion A6                 vm_A6
# 332  ventromedial abdominal ganglion A7                 vm_A7
# 333  ventromedial abdominal ganglion A7                 vm_A7
# 334  ventromedial abdominal ganglion A8                 vm_A8
# 335  ventromedial abdominal ganglion A8                 vm_A8
# 336  ventromedial abdominal ganglion A9                 vm_A9
# 337  ventromedial abdominal ganglion A9                 vm_A9
# 338               ventromedial cerebrum                   VMC
# 339               ventromedial cerebrum                   VMC
# 340         ventromedial labial segment                 vm_LB
# 341         ventromedial labial segment                 vm_LB
# 342     ventromedial mandibular segment                 vm_MD
# 343     ventromedial mandibular segment                 vm_MD
# 344      ventromedial maxillary segment                 vm_MX
# 345      ventromedial maxillary segment                 vm_MX
# 346   ventromedial thoracic ganglion T1                 vm_T1
# 347   ventromedial thoracic ganglion T1                 vm_T1
# 348   ventromedial thoracic ganglion T2                 vm_T2
# 349   ventromedial thoracic ganglion T2                 vm_T2
# 350   ventromedial thoracic ganglion T3                 vm_T3
# 351   ventromedial thoracic ganglion T3                 vm_T3
# 352          ventromedial tritocerebrum                 vm_TR
# 353          ventromedial tritocerebrum                 vm_TR
# 354                       vertical lobe                    VL
#
#     larvalbrain_hemisphere  larvalbrain_id
# 0                        L             285
# 1                        R             463
# 2                        L             276
# 3                        R             454
# 4                        L             277
# 5                        R             455
# 6                        L             278
# 7                        R             456
# 8                        L             279
# 9                        R             457
# 10                       L             280
# 11                       R             458
# 12                       L             281
# 13                       R             459
# 14                       L             282
# 15                       R             460
# 16                       L             283
# 17                       R             461
# 18                       L             284
# 19                       R             462
# 20                       L             286
# 21                       R             464
# 22                       L             287
# 23                       R             465
# 24                       L             288
# 25                       R             466
# 26                       L             289
# 27                       R             467
# 28                       L             290
# 29                       R             468
# ..                     ...             ...
# 325                      R             618
# 326                      L             441
# 327                      R             619
# 328                      L             442
# 329                      R             620
# 330                      L             443
# 331                      R             621
# 332                      L             444
# 333                      R             622
# 334                      L             445
# 335                      R             623
# 336                      L             446
# 337                      R             624
# 338                      L             437
# 339                      R             615
# 340                      L             447
# 341                      R             625
# 342                      L             448
# 343                      R             626
# 344                      L             449
# 345                      R             627
# 346                      L             450
# 347                      R             628
# 348                      L             451
# 349                      R             629
# 350                      L             452
# 351                      R             630
# 352                      L             453
# 353                      R             631
# 354                      L             421
#
# [355 rows x 4 columns]

# %%
def search_function(search_term: str):
    output_id=list()
    output_label=list()
    for n in fbbt['graphs'][0]['nodes']:
        try:
            test_result = True
            for word in str.lower(search_term).split(" "):
                if word not in str.lower(n['lbl']): test_result = False
                else: continue
            if test_result == True:
                output_id.append(n['id'])
                output_label.append(n['lbl'])
        except KeyError: continue
        try:
            for s in n['meta']['synonyms']:
                test_result = True
                for word in str.lower(search_term).split(" "):
                    if word not in str.lower(s['val']) or n['id'] in output_id: test_result = False
                    else: continue
                if test_result == True:
                    output_id.append(n['id'])
                    output_label.append(n['lbl'])
        except KeyError: continue
    return dict(zip(output_id,output_label))

# %%
neuropil_segments_raw = search_function("neuropil larva segment")
neuropil_segments = {}
for key, val in neuropil_segments_raw.items():
    if any(char.isdigit() for char in val):
        neuropil_segments.update({key : val})

#neuropil_segments
# Out:
# {'http://purl.obolibrary.org/obo/FBbt_00015093': 'dorsolateral neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015092': 'centromedial neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015091': 'centrolateral neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015090': 'central neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015097': 'central neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015096': 'ventromedial neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015095': 'ventrolateral neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015094': 'dorsomedial neuropil of larval segment A8',
#  'http://purl.obolibrary.org/obo/FBbt_00015042': 'centrolateral neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015046': 'ventrolateral neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015045': 'dorsomedial neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015044': 'dorsolateral neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015043': 'centromedial neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015017': 'dorsomedial neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015016': 'dorsolateral neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015015': 'centromedial neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015014': 'centrolateral neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015019': 'ventromedial neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015018': 'ventrolateral neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015020': 'central neuropil of larval segment T1',
#  'http://purl.obolibrary.org/obo/FBbt_00015006': 'central neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015005': 'ventromedial neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015004': 'ventrolateral neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015003': 'dorsomedial neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015009': 'dorsolateral neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015008': 'centromedial neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015007': 'centrolateral neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015013': 'central neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015012': 'ventromedial neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015011': 'ventrolateral neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015010': 'dorsomedial neuropil of larval segment T3',
#  'http://purl.obolibrary.org/obo/FBbt_00015082': 'ventromedial neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015081': 'ventrolateral neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015080': 'dorsomedial neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015086': 'dorsolateral neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015085': 'centromedial neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015084': 'centrolateral neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015083': 'central neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015089': 'ventromedial neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015088': 'ventrolateral neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015087': 'dorsomedial neuropil of larval segment A7',
#  'http://purl.obolibrary.org/obo/FBbt_00015069': 'central neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015071': 'centromedial neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015070': 'centrolateral neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015075': 'ventromedial neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015074': 'ventrolateral neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015073': 'dorsomedial neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015072': 'dorsolateral neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015079': 'dorsolateral neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015078': 'centromedial neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015077': 'centrolateral neuropil of larval segment A6',
#  'http://purl.obolibrary.org/obo/FBbt_00015076': 'central neuropil of larval segment A5',
#  'http://purl.obolibrary.org/obo/FBbt_00015059': 'dorsomedial neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015058': 'dorsolateral neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015060': 'ventrolateral neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015064': 'centromedial neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015063': 'centrolateral neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015062': 'central neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015061': 'ventromedial neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015068': 'ventromedial neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015067': 'ventrolateral neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015066': 'dorsomedial neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015065': 'dorsolateral neuropil of larval segment A4',
#  'http://purl.obolibrary.org/obo/FBbt_00015049': 'centrolateral neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015048': 'central neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015047': 'ventromedial neuropil of larval segment A1',
#  'http://purl.obolibrary.org/obo/FBbt_00015053': 'ventrolateral neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015052': 'dorsomedial neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015051': 'dorsolateral neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015050': 'centromedial neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015057': 'centromedial neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015056': 'centrolateral neuropil of larval segment A3',
#  'http://purl.obolibrary.org/obo/FBbt_00015055': 'central neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015054': 'ventromedial neuropil of larval segment A2',
#  'http://purl.obolibrary.org/obo/FBbt_00015002': 'dorsolateral neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015001': 'centromedial neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00015000': 'centrolateral neuropil of larval segment T2',
#  'http://purl.obolibrary.org/obo/FBbt_00007716': 'central neuropil of larval segment A9',
#  'http://purl.obolibrary.org/obo/FBbt_00007714': 'dorsal neuropil of larval segment A9',
#  'http://purl.obolibrary.org/obo/FBbt_00007715': 'ventral neuropil of larval segment A9'}

# %%
fbbt_names = {'fbbt_uri' : list(neuropil_segments.keys()), \
              'fbbt_name' : list(neuropil_segments.values()), \
             'lb_synonym' : list([""] * len(neuropil_segments))}

# %%
mapping_table = pd.DataFrame(fbbt_names)
#mapping_table
# Out:
#                                         fbbt_uri  \
# 0   http://purl.obolibrary.org/obo/FBbt_00015093
# 1   http://purl.obolibrary.org/obo/FBbt_00015092
# 2   http://purl.obolibrary.org/obo/FBbt_00015091
# 3   http://purl.obolibrary.org/obo/FBbt_00015090
# 4   http://purl.obolibrary.org/obo/FBbt_00015097
# 5   http://purl.obolibrary.org/obo/FBbt_00015096
# 6   http://purl.obolibrary.org/obo/FBbt_00015095
# 7   http://purl.obolibrary.org/obo/FBbt_00015094
# 8   http://purl.obolibrary.org/obo/FBbt_00015042
# 9   http://purl.obolibrary.org/obo/FBbt_00015046
# 10  http://purl.obolibrary.org/obo/FBbt_00015045
# 11  http://purl.obolibrary.org/obo/FBbt_00015044
# 12  http://purl.obolibrary.org/obo/FBbt_00015043
# 13  http://purl.obolibrary.org/obo/FBbt_00015017
# 14  http://purl.obolibrary.org/obo/FBbt_00015016
# 15  http://purl.obolibrary.org/obo/FBbt_00015015
# 16  http://purl.obolibrary.org/obo/FBbt_00015014
# 17  http://purl.obolibrary.org/obo/FBbt_00015019
# 18  http://purl.obolibrary.org/obo/FBbt_00015018
# 19  http://purl.obolibrary.org/obo/FBbt_00015020
# 20  http://purl.obolibrary.org/obo/FBbt_00015006
# 21  http://purl.obolibrary.org/obo/FBbt_00015005
# 22  http://purl.obolibrary.org/obo/FBbt_00015004
# 23  http://purl.obolibrary.org/obo/FBbt_00015003
# 24  http://purl.obolibrary.org/obo/FBbt_00015009
# 25  http://purl.obolibrary.org/obo/FBbt_00015008
# 26  http://purl.obolibrary.org/obo/FBbt_00015007
# 27  http://purl.obolibrary.org/obo/FBbt_00015013
# 28  http://purl.obolibrary.org/obo/FBbt_00015012
# 29  http://purl.obolibrary.org/obo/FBbt_00015011
# ..                                           ...
# 50  http://purl.obolibrary.org/obo/FBbt_00015077
# 51  http://purl.obolibrary.org/obo/FBbt_00015076
# 52  http://purl.obolibrary.org/obo/FBbt_00015059
# 53  http://purl.obolibrary.org/obo/FBbt_00015058
# 54  http://purl.obolibrary.org/obo/FBbt_00015060
# 55  http://purl.obolibrary.org/obo/FBbt_00015064
# 56  http://purl.obolibrary.org/obo/FBbt_00015063
# 57  http://purl.obolibrary.org/obo/FBbt_00015062
# 58  http://purl.obolibrary.org/obo/FBbt_00015061
# 59  http://purl.obolibrary.org/obo/FBbt_00015068
# 60  http://purl.obolibrary.org/obo/FBbt_00015067
# 61  http://purl.obolibrary.org/obo/FBbt_00015066
# 62  http://purl.obolibrary.org/obo/FBbt_00015065
# 63  http://purl.obolibrary.org/obo/FBbt_00015049
# 64  http://purl.obolibrary.org/obo/FBbt_00015048
# 65  http://purl.obolibrary.org/obo/FBbt_00015047
# 66  http://purl.obolibrary.org/obo/FBbt_00015053
# 67  http://purl.obolibrary.org/obo/FBbt_00015052
# 68  http://purl.obolibrary.org/obo/FBbt_00015051
# 69  http://purl.obolibrary.org/obo/FBbt_00015050
# 70  http://purl.obolibrary.org/obo/FBbt_00015057
# 71  http://purl.obolibrary.org/obo/FBbt_00015056
# 72  http://purl.obolibrary.org/obo/FBbt_00015055
# 73  http://purl.obolibrary.org/obo/FBbt_00015054
# 74  http://purl.obolibrary.org/obo/FBbt_00015002
# 75  http://purl.obolibrary.org/obo/FBbt_00015001
# 76  http://purl.obolibrary.org/obo/FBbt_00015000
# 77  http://purl.obolibrary.org/obo/FBbt_00007716
# 78  http://purl.obolibrary.org/obo/FBbt_00007714
# 79  http://purl.obolibrary.org/obo/FBbt_00007715
#
#                                       fbbt_name lb_synonym
# 0    dorsolateral neuropil of larval segment A8
# 1    centromedial neuropil of larval segment A8
# 2   centrolateral neuropil of larval segment A8
# 3         central neuropil of larval segment A7
# 4         central neuropil of larval segment A8
# 5    ventromedial neuropil of larval segment A8
# 6   ventrolateral neuropil of larval segment A8
# 7     dorsomedial neuropil of larval segment A8
# 8   centrolateral neuropil of larval segment A1
# 9   ventrolateral neuropil of larval segment A1
# 10    dorsomedial neuropil of larval segment A1
# 11   dorsolateral neuropil of larval segment A1
# 12   centromedial neuropil of larval segment A1
# 13    dorsomedial neuropil of larval segment T1
# 14   dorsolateral neuropil of larval segment T1
# 15   centromedial neuropil of larval segment T1
# 16  centrolateral neuropil of larval segment T1
# 17   ventromedial neuropil of larval segment T1
# 18  ventrolateral neuropil of larval segment T1
# 19        central neuropil of larval segment T1
# 20        central neuropil of larval segment T2
# 21   ventromedial neuropil of larval segment T2
# 22  ventrolateral neuropil of larval segment T2
# 23    dorsomedial neuropil of larval segment T2
# 24   dorsolateral neuropil of larval segment T3
# 25   centromedial neuropil of larval segment T3
# 26  centrolateral neuropil of larval segment T3
# 27        central neuropil of larval segment T3
# 28   ventromedial neuropil of larval segment T3
# 29  ventrolateral neuropil of larval segment T3
# ..                                          ...        ...
# 50  centrolateral neuropil of larval segment A6
# 51        central neuropil of larval segment A5
# 52    dorsomedial neuropil of larval segment A3
# 53   dorsolateral neuropil of larval segment A3
# 54  ventrolateral neuropil of larval segment A3
# 55   centromedial neuropil of larval segment A4
# 56  centrolateral neuropil of larval segment A4
# 57        central neuropil of larval segment A3
# 58   ventromedial neuropil of larval segment A3
# 59   ventromedial neuropil of larval segment A4
# 60  ventrolateral neuropil of larval segment A4
# 61    dorsomedial neuropil of larval segment A4
# 62   dorsolateral neuropil of larval segment A4
# 63  centrolateral neuropil of larval segment A2
# 64        central neuropil of larval segment A1
# 65   ventromedial neuropil of larval segment A1
# 66  ventrolateral neuropil of larval segment A2
# 67    dorsomedial neuropil of larval segment A2
# 68   dorsolateral neuropil of larval segment A2
# 69   centromedial neuropil of larval segment A2
# 70   centromedial neuropil of larval segment A3
# 71  centrolateral neuropil of larval segment A3
# 72        central neuropil of larval segment A2
# 73   ventromedial neuropil of larval segment A2
# 74   dorsolateral neuropil of larval segment T2
# 75   centromedial neuropil of larval segment T2
# 76  centrolateral neuropil of larval segment T2
# 77        central neuropil of larval segment A9
# 78         dorsal neuropil of larval segment A9
# 79        ventral neuropil of larval segment A9
#
# [80 rows x 3 columns]

# %%
segment_map = {'A1' : 'abdominal ganglion A1',
               'A2' : 'abdominal ganglion A2',
               'A3' : 'abdominal ganglion A3',
               'A4' : 'abdominal ganglion A4',
               'A5' : 'abdominal ganglion A5',
               'A6' : 'abdominal ganglion A6',
               'A7' : 'abdominal ganglion A7',
               'A8' : 'abdominal ganglion A8',
               'A9' : 'abdominal ganglion A9',
               'T1' : 'thoracic ganglion T1',
               'T2' : 'thoracic ganglion T2',
               'T3' : 'thoracic ganglion T3',
              }

# %%
for i in mapping_table.index:
    synonym = "larval " + mapping_table.fbbt_name[i].split(" ")[0] + " "
    synonym += segment_map[mapping_table.fbbt_name[i].split(" ")[-1]]
    mapping_table.lb_synonym[i] = synonym
    
mapping_table
# Out:
#                                         fbbt_uri  \
# 0   http://purl.obolibrary.org/obo/FBbt_00015093
# 1   http://purl.obolibrary.org/obo/FBbt_00015092
# 2   http://purl.obolibrary.org/obo/FBbt_00015091
# 3   http://purl.obolibrary.org/obo/FBbt_00015090
# 4   http://purl.obolibrary.org/obo/FBbt_00015097
# 5   http://purl.obolibrary.org/obo/FBbt_00015096
# 6   http://purl.obolibrary.org/obo/FBbt_00015095
# 7   http://purl.obolibrary.org/obo/FBbt_00015094
# 8   http://purl.obolibrary.org/obo/FBbt_00015042
# 9   http://purl.obolibrary.org/obo/FBbt_00015046
# 10  http://purl.obolibrary.org/obo/FBbt_00015045
# 11  http://purl.obolibrary.org/obo/FBbt_00015044
# 12  http://purl.obolibrary.org/obo/FBbt_00015043
# 13  http://purl.obolibrary.org/obo/FBbt_00015017
# 14  http://purl.obolibrary.org/obo/FBbt_00015016
# 15  http://purl.obolibrary.org/obo/FBbt_00015015
# 16  http://purl.obolibrary.org/obo/FBbt_00015014
# 17  http://purl.obolibrary.org/obo/FBbt_00015019
# 18  http://purl.obolibrary.org/obo/FBbt_00015018
# 19  http://purl.obolibrary.org/obo/FBbt_00015020
# 20  http://purl.obolibrary.org/obo/FBbt_00015006
# 21  http://purl.obolibrary.org/obo/FBbt_00015005
# 22  http://purl.obolibrary.org/obo/FBbt_00015004
# 23  http://purl.obolibrary.org/obo/FBbt_00015003
# 24  http://purl.obolibrary.org/obo/FBbt_00015009
# 25  http://purl.obolibrary.org/obo/FBbt_00015008
# 26  http://purl.obolibrary.org/obo/FBbt_00015007
# 27  http://purl.obolibrary.org/obo/FBbt_00015013
# 28  http://purl.obolibrary.org/obo/FBbt_00015012
# 29  http://purl.obolibrary.org/obo/FBbt_00015011
# ..                                           ...
# 50  http://purl.obolibrary.org/obo/FBbt_00015077
# 51  http://purl.obolibrary.org/obo/FBbt_00015076
# 52  http://purl.obolibrary.org/obo/FBbt_00015059
# 53  http://purl.obolibrary.org/obo/FBbt_00015058
# 54  http://purl.obolibrary.org/obo/FBbt_00015060
# 55  http://purl.obolibrary.org/obo/FBbt_00015064
# 56  http://purl.obolibrary.org/obo/FBbt_00015063
# 57  http://purl.obolibrary.org/obo/FBbt_00015062
# 58  http://purl.obolibrary.org/obo/FBbt_00015061
# 59  http://purl.obolibrary.org/obo/FBbt_00015068
# 60  http://purl.obolibrary.org/obo/FBbt_00015067
# 61  http://purl.obolibrary.org/obo/FBbt_00015066
# 62  http://purl.obolibrary.org/obo/FBbt_00015065
# 63  http://purl.obolibrary.org/obo/FBbt_00015049
# 64  http://purl.obolibrary.org/obo/FBbt_00015048
# 65  http://purl.obolibrary.org/obo/FBbt_00015047
# 66  http://purl.obolibrary.org/obo/FBbt_00015053
# 67  http://purl.obolibrary.org/obo/FBbt_00015052
# 68  http://purl.obolibrary.org/obo/FBbt_00015051
# 69  http://purl.obolibrary.org/obo/FBbt_00015050
# 70  http://purl.obolibrary.org/obo/FBbt_00015057
# 71  http://purl.obolibrary.org/obo/FBbt_00015056
# 72  http://purl.obolibrary.org/obo/FBbt_00015055
# 73  http://purl.obolibrary.org/obo/FBbt_00015054
# 74  http://purl.obolibrary.org/obo/FBbt_00015002
# 75  http://purl.obolibrary.org/obo/FBbt_00015001
# 76  http://purl.obolibrary.org/obo/FBbt_00015000
# 77  http://purl.obolibrary.org/obo/FBbt_00007716
# 78  http://purl.obolibrary.org/obo/FBbt_00007714
# 79  http://purl.obolibrary.org/obo/FBbt_00007715
#
#                                       fbbt_name  \
# 0    dorsolateral neuropil of larval segment A8
# 1    centromedial neuropil of larval segment A8
# 2   centrolateral neuropil of larval segment A8
# 3         central neuropil of larval segment A7
# 4         central neuropil of larval segment A8
# 5    ventromedial neuropil of larval segment A8
# 6   ventrolateral neuropil of larval segment A8
# 7     dorsomedial neuropil of larval segment A8
# 8   centrolateral neuropil of larval segment A1
# 9   ventrolateral neuropil of larval segment A1
# 10    dorsomedial neuropil of larval segment A1
# 11   dorsolateral neuropil of larval segment A1
# 12   centromedial neuropil of larval segment A1
# 13    dorsomedial neuropil of larval segment T1
# 14   dorsolateral neuropil of larval segment T1
# 15   centromedial neuropil of larval segment T1
# 16  centrolateral neuropil of larval segment T1
# 17   ventromedial neuropil of larval segment T1
# 18  ventrolateral neuropil of larval segment T1
# 19        central neuropil of larval segment T1
# 20        central neuropil of larval segment T2
# 21   ventromedial neuropil of larval segment T2
# 22  ventrolateral neuropil of larval segment T2
# 23    dorsomedial neuropil of larval segment T2
# 24   dorsolateral neuropil of larval segment T3
# 25   centromedial neuropil of larval segment T3
# 26  centrolateral neuropil of larval segment T3
# 27        central neuropil of larval segment T3
# 28   ventromedial neuropil of larval segment T3
# 29  ventrolateral neuropil of larval segment T3
# ..                                          ...
# 50  centrolateral neuropil of larval segment A6
# 51        central neuropil of larval segment A5
# 52    dorsomedial neuropil of larval segment A3
# 53   dorsolateral neuropil of larval segment A3
# 54  ventrolateral neuropil of larval segment A3
# 55   centromedial neuropil of larval segment A4
# 56  centrolateral neuropil of larval segment A4
# 57        central neuropil of larval segment A3
# 58   ventromedial neuropil of larval segment A3
# 59   ventromedial neuropil of larval segment A4
# 60  ventrolateral neuropil of larval segment A4
# 61    dorsomedial neuropil of larval segment A4
# 62   dorsolateral neuropil of larval segment A4
# 63  centrolateral neuropil of larval segment A2
# 64        central neuropil of larval segment A1
# 65   ventromedial neuropil of larval segment A1
# 66  ventrolateral neuropil of larval segment A2
# 67    dorsomedial neuropil of larval segment A2
# 68   dorsolateral neuropil of larval segment A2
# 69   centromedial neuropil of larval segment A2
# 70   centromedial neuropil of larval segment A3
# 71  centrolateral neuropil of larval segment A3
# 72        central neuropil of larval segment A2
# 73   ventromedial neuropil of larval segment A2
# 74   dorsolateral neuropil of larval segment T2
# 75   centromedial neuropil of larval segment T2
# 76  centrolateral neuropil of larval segment T2
# 77        central neuropil of larval segment A9
# 78         dorsal neuropil of larval segment A9
# 79        ventral neuropil of larval segment A9
#
#                                     lb_synonym
# 0    larval dorsolateral abdominal ganglion A8
# 1    larval centromedial abdominal ganglion A8
# 2   larval centrolateral abdominal ganglion A8
# 3         larval central abdominal ganglion A7
# 4         larval central abdominal ganglion A8
# 5    larval ventromedial abdominal ganglion A8
# 6   larval ventrolateral abdominal ganglion A8
# 7     larval dorsomedial abdominal ganglion A8
# 8   larval centrolateral abdominal ganglion A1
# 9   larval ventrolateral abdominal ganglion A1
# 10    larval dorsomedial abdominal ganglion A1
# 11   larval dorsolateral abdominal ganglion A1
# 12   larval centromedial abdominal ganglion A1
# 13     larval dorsomedial thoracic ganglion T1
# 14    larval dorsolateral thoracic ganglion T1
# 15    larval centromedial thoracic ganglion T1
# 16   larval centrolateral thoracic ganglion T1
# 17    larval ventromedial thoracic ganglion T1
# 18   larval ventrolateral thoracic ganglion T1
# 19         larval central thoracic ganglion T1
# 20         larval central thoracic ganglion T2
# 21    larval ventromedial thoracic ganglion T2
# 22   larval ventrolateral thoracic ganglion T2
# 23     larval dorsomedial thoracic ganglion T2
# 24    larval dorsolateral thoracic ganglion T3
# 25    larval centromedial thoracic ganglion T3
# 26   larval centrolateral thoracic ganglion T3
# 27         larval central thoracic ganglion T3
# 28    larval ventromedial thoracic ganglion T3
# 29   larval ventrolateral thoracic ganglion T3
# ..                                         ...
# 50  larval centrolateral abdominal ganglion A6
# 51        larval central abdominal ganglion A5
# 52    larval dorsomedial abdominal ganglion A3
# 53   larval dorsolateral abdominal ganglion A3
# 54  larval ventrolateral abdominal ganglion A3
# 55   larval centromedial abdominal ganglion A4
# 56  larval centrolateral abdominal ganglion A4
# 57        larval central abdominal ganglion A3
# 58   larval ventromedial abdominal ganglion A3
# 59   larval ventromedial abdominal ganglion A4
# 60  larval ventrolateral abdominal ganglion A4
# 61    larval dorsomedial abdominal ganglion A4
# 62   larval dorsolateral abdominal ganglion A4
# 63  larval centrolateral abdominal ganglion A2
# 64        larval central abdominal ganglion A1
# 65   larval ventromedial abdominal ganglion A1
# 66  larval ventrolateral abdominal ganglion A2
# 67    larval dorsomedial abdominal ganglion A2
# 68   larval dorsolateral abdominal ganglion A2
# 69   larval centromedial abdominal ganglion A2
# 70   larval centromedial abdominal ganglion A3
# 71  larval centrolateral abdominal ganglion A3
# 72        larval central abdominal ganglion A2
# 73   larval ventromedial abdominal ganglion A2
# 74    larval dorsolateral thoracic ganglion T2
# 75    larval centromedial thoracic ganglion T2
# 76   larval centrolateral thoracic ganglion T2
# 77        larval central abdominal ganglion A9
# 78         larval dorsal abdominal ganglion A9
# 79        larval ventral abdominal ganglion A9
#
# [80 rows x 3 columns]

# %%
template_seed = OrderedDict([ ('ID' , 'ID'), ('CLASS_TYPE' , 'CLASS_TYPE'),\
                             ('RDF_Type' , 'TYPE' )])

template_seed.update([("Synonym" , "A oboInOwl:hasExactSynonym")])

template = pd.DataFrame.from_records([template_seed])

template
# Out:
#    ID  CLASS_TYPE RDF_Type                     Synonym
# 0  ID  CLASS_TYPE     TYPE  A oboInOwl:hasExactSynonym

# %%
for i in mapping_table.index:

    row_od = OrderedDict([]) #new template row as an empty ordered dictionary
    for c in template.columns: #make columns and blank data for new template row
        row_od.update([(c , "")])
    
    #these are the same in each row
    row_od["CLASS_TYPE"] = "subclass"
    row_od["RDF_Type"] = "owl:Class"

    #easy to generate data
    row_od["ID"] = mapping_table.fbbt_uri[i]
    row_od["Synonym"] = mapping_table.lb_synonym[i]

    new_row = pd.DataFrame.from_records([row_od])
    template = pd.concat([template, new_row], ignore_index=True, sort=False)

template
# Out:
#                                               ID  CLASS_TYPE   RDF_Type  \
# 0                                             ID  CLASS_TYPE       TYPE
# 1   http://purl.obolibrary.org/obo/FBbt_00015093    subclass  owl:Class
# 2   http://purl.obolibrary.org/obo/FBbt_00015092    subclass  owl:Class
# 3   http://purl.obolibrary.org/obo/FBbt_00015091    subclass  owl:Class
# 4   http://purl.obolibrary.org/obo/FBbt_00015090    subclass  owl:Class
# 5   http://purl.obolibrary.org/obo/FBbt_00015097    subclass  owl:Class
# 6   http://purl.obolibrary.org/obo/FBbt_00015096    subclass  owl:Class
# 7   http://purl.obolibrary.org/obo/FBbt_00015095    subclass  owl:Class
# 8   http://purl.obolibrary.org/obo/FBbt_00015094    subclass  owl:Class
# 9   http://purl.obolibrary.org/obo/FBbt_00015042    subclass  owl:Class
# 10  http://purl.obolibrary.org/obo/FBbt_00015046    subclass  owl:Class
# 11  http://purl.obolibrary.org/obo/FBbt_00015045    subclass  owl:Class
# 12  http://purl.obolibrary.org/obo/FBbt_00015044    subclass  owl:Class
# 13  http://purl.obolibrary.org/obo/FBbt_00015043    subclass  owl:Class
# 14  http://purl.obolibrary.org/obo/FBbt_00015017    subclass  owl:Class
# 15  http://purl.obolibrary.org/obo/FBbt_00015016    subclass  owl:Class
# 16  http://purl.obolibrary.org/obo/FBbt_00015015    subclass  owl:Class
# 17  http://purl.obolibrary.org/obo/FBbt_00015014    subclass  owl:Class
# 18  http://purl.obolibrary.org/obo/FBbt_00015019    subclass  owl:Class
# 19  http://purl.obolibrary.org/obo/FBbt_00015018    subclass  owl:Class
# 20  http://purl.obolibrary.org/obo/FBbt_00015020    subclass  owl:Class
# 21  http://purl.obolibrary.org/obo/FBbt_00015006    subclass  owl:Class
# 22  http://purl.obolibrary.org/obo/FBbt_00015005    subclass  owl:Class
# 23  http://purl.obolibrary.org/obo/FBbt_00015004    subclass  owl:Class
# 24  http://purl.obolibrary.org/obo/FBbt_00015003    subclass  owl:Class
# 25  http://purl.obolibrary.org/obo/FBbt_00015009    subclass  owl:Class
# 26  http://purl.obolibrary.org/obo/FBbt_00015008    subclass  owl:Class
# 27  http://purl.obolibrary.org/obo/FBbt_00015007    subclass  owl:Class
# 28  http://purl.obolibrary.org/obo/FBbt_00015013    subclass  owl:Class
# 29  http://purl.obolibrary.org/obo/FBbt_00015012    subclass  owl:Class
# ..                                           ...         ...        ...
# 51  http://purl.obolibrary.org/obo/FBbt_00015077    subclass  owl:Class
# 52  http://purl.obolibrary.org/obo/FBbt_00015076    subclass  owl:Class
# 53  http://purl.obolibrary.org/obo/FBbt_00015059    subclass  owl:Class
# 54  http://purl.obolibrary.org/obo/FBbt_00015058    subclass  owl:Class
# 55  http://purl.obolibrary.org/obo/FBbt_00015060    subclass  owl:Class
# 56  http://purl.obolibrary.org/obo/FBbt_00015064    subclass  owl:Class
# 57  http://purl.obolibrary.org/obo/FBbt_00015063    subclass  owl:Class
# 58  http://purl.obolibrary.org/obo/FBbt_00015062    subclass  owl:Class
# 59  http://purl.obolibrary.org/obo/FBbt_00015061    subclass  owl:Class
# 60  http://purl.obolibrary.org/obo/FBbt_00015068    subclass  owl:Class
# 61  http://purl.obolibrary.org/obo/FBbt_00015067    subclass  owl:Class
# 62  http://purl.obolibrary.org/obo/FBbt_00015066    subclass  owl:Class
# 63  http://purl.obolibrary.org/obo/FBbt_00015065    subclass  owl:Class
# 64  http://purl.obolibrary.org/obo/FBbt_00015049    subclass  owl:Class
# 65  http://purl.obolibrary.org/obo/FBbt_00015048    subclass  owl:Class
# 66  http://purl.obolibrary.org/obo/FBbt_00015047    subclass  owl:Class
# 67  http://purl.obolibrary.org/obo/FBbt_00015053    subclass  owl:Class
# 68  http://purl.obolibrary.org/obo/FBbt_00015052    subclass  owl:Class
# 69  http://purl.obolibrary.org/obo/FBbt_00015051    subclass  owl:Class
# 70  http://purl.obolibrary.org/obo/FBbt_00015050    subclass  owl:Class
# 71  http://purl.obolibrary.org/obo/FBbt_00015057    subclass  owl:Class
# 72  http://purl.obolibrary.org/obo/FBbt_00015056    subclass  owl:Class
# 73  http://purl.obolibrary.org/obo/FBbt_00015055    subclass  owl:Class
# 74  http://purl.obolibrary.org/obo/FBbt_00015054    subclass  owl:Class
# 75  http://purl.obolibrary.org/obo/FBbt_00015002    subclass  owl:Class
# 76  http://purl.obolibrary.org/obo/FBbt_00015001    subclass  owl:Class
# 77  http://purl.obolibrary.org/obo/FBbt_00015000    subclass  owl:Class
# 78  http://purl.obolibrary.org/obo/FBbt_00007716    subclass  owl:Class
# 79  http://purl.obolibrary.org/obo/FBbt_00007714    subclass  owl:Class
# 80  http://purl.obolibrary.org/obo/FBbt_00007715    subclass  owl:Class
#
#                                        Synonym
# 0                   A oboInOwl:hasExactSynonym
# 1    larval dorsolateral abdominal ganglion A8
# 2    larval centromedial abdominal ganglion A8
# 3   larval centrolateral abdominal ganglion A8
# 4         larval central abdominal ganglion A7
# 5         larval central abdominal ganglion A8
# 6    larval ventromedial abdominal ganglion A8
# 7   larval ventrolateral abdominal ganglion A8
# 8     larval dorsomedial abdominal ganglion A8
# 9   larval centrolateral abdominal ganglion A1
# 10  larval ventrolateral abdominal ganglion A1
# 11    larval dorsomedial abdominal ganglion A1
# 12   larval dorsolateral abdominal ganglion A1
# 13   larval centromedial abdominal ganglion A1
# 14     larval dorsomedial thoracic ganglion T1
# 15    larval dorsolateral thoracic ganglion T1
# 16    larval centromedial thoracic ganglion T1
# 17   larval centrolateral thoracic ganglion T1
# 18    larval ventromedial thoracic ganglion T1
# 19   larval ventrolateral thoracic ganglion T1
# 20         larval central thoracic ganglion T1
# 21         larval central thoracic ganglion T2
# 22    larval ventromedial thoracic ganglion T2
# 23   larval ventrolateral thoracic ganglion T2
# 24     larval dorsomedial thoracic ganglion T2
# 25    larval dorsolateral thoracic ganglion T3
# 26    larval centromedial thoracic ganglion T3
# 27   larval centrolateral thoracic ganglion T3
# 28         larval central thoracic ganglion T3
# 29    larval ventromedial thoracic ganglion T3
# ..                                         ...
# 51  larval centrolateral abdominal ganglion A6
# 52        larval central abdominal ganglion A5
# 53    larval dorsomedial abdominal ganglion A3
# 54   larval dorsolateral abdominal ganglion A3
# 55  larval ventrolateral abdominal ganglion A3
# 56   larval centromedial abdominal ganglion A4
# 57  larval centrolateral abdominal ganglion A4
# 58        larval central abdominal ganglion A3
# 59   larval ventromedial abdominal ganglion A3
# 60   larval ventromedial abdominal ganglion A4
# 61  larval ventrolateral abdominal ganglion A4
# 62    larval dorsomedial abdominal ganglion A4
# 63   larval dorsolateral abdominal ganglion A4
# 64  larval centrolateral abdominal ganglion A2
# 65        larval central abdominal ganglion A1
# 66   larval ventromedial abdominal ganglion A1
# 67  larval ventrolateral abdominal ganglion A2
# 68    larval dorsomedial abdominal ganglion A2
# 69   larval dorsolateral abdominal ganglion A2
# 70   larval centromedial abdominal ganglion A2
# 71   larval centromedial abdominal ganglion A3
# 72  larval centrolateral abdominal ganglion A3
# 73        larval central abdominal ganglion A2
# 74   larval ventromedial abdominal ganglion A2
# 75    larval dorsolateral thoracic ganglion T2
# 76    larval centromedial thoracic ganglion T2
# 77   larval centrolateral thoracic ganglion T2
# 78        larval central abdominal ganglion A9
# 79         larval dorsal abdominal ganglion A9
# 80        larval ventral abdominal ganglion A9
#
# [81 rows x 4 columns]

# %%
template.to_csv("./template.tsv", sep = "\t", header=True, index=False)
